# %%
import json
import re
from os import path
from glob import glob
from natsort import natsorted
from collections import defaultdict
from bs4 import BeautifulSoup

# %%
BILARA_DATA_DIR = './bilara-data/'
SC_DATA_DIR = './sc-data/'

# %%
# load acronyms and author data
with open(path.join(SC_DATA_DIR, 'misc/uid_expansion.json')) as f:
    acronyms = { a['uid']: a for a in json.loads(f.read()) }

with open(path.join(SC_DATA_DIR, 'additional-info/author_edition.json')) as f:
    authors = { a['long_name']: a for a in json.loads(f.read()) }

# %%
# source: https://www.oreilly.com/library/view/python-cookbook/0596001673/ch03s24.html
def int_to_roman(inp):
    """ Convert an integer to a Roman numeral. """

    if not isinstance(inp, type(1)):
        raise TypeError("expected integer, got %s" % type(inp))
    if not 0 < inp < 4000:
        raise ValueError("Argument must be between 1 and 3999")
    ints = (1000, 900,  500, 400, 100,  90, 50,  40, 10,  9,   5,  4,   1)
    nums = ('M',  'CM', 'D', 'CD','C', 'XC','L','XL','X','IX','V','IV','I')
    result = []
    for i in range(len(ints)):
        count = int(inp / ints[i])
        result.append(nums[i] * count)
        inp -= ints[i] * count
    
    return ''.join(result).lower()

# %%
def extract_vol_pos(pts_ref: str):
    """ Extract volume and position from reference id. """
    
    match_position = re.search(r'([0-9]+\.)?([0-9]+)$', pts_ref)
    assert match_position != None and match_position.group(2) != None 

    volume = match_position.group(1)
    volume = int_to_roman(int(volume.replace('.', ''))) if volume else None
    position = int(match_position.group(2))
    
    return '%s %i' % (volume, position) if volume else position

# %%
def extract_book(uid: str):
    """ Extract book acronym from uid. """

    book_id = re.match(r'^([^0-9]+)', uid).group(1)
    book_id = book_id.replace('pli-tv-vb-', '').replace('pli-tv-bi-', '').replace('pli-tv-bu', '').replace('pli-tv', '')
    
    assert book_id in acronyms
    assert acronyms[book_id]['acro']
    
    return acronyms[book_id]['acro']

# %%
def extract_edition(pts_ref: str):
    """ Extract edition number if exists. """
    
    edition = ''

    m = re.search(r'pts-vp-pli(1ed|2ed)', pts_ref)
    if m and m.group(1):
        edition = m.group(1)
    
    return edition

# %%
def format_pts(uid: str, pts_ref: str):
    """ Use SC segment reference and uid to convert PTS reference """
    
    edition = extract_edition(pts_ref)
    book = extract_book(uid)
    vol_pos = extract_vol_pos(pts_ref)
    
    return '%s (%s) %s' % (book, edition, vol_pos) if edition else '%s %s' % (book, vol_pos)

# %%
pts_to_refs = defaultdict(list)

# get all possible cross-refs for every pts ref
for ref_file in natsorted(glob(path.join(BILARA_DATA_DIR, 'reference/pli/ms/sutta/**/*.json'), recursive=True)):   
    with open(ref_file) as f:
        ref_data = json.loads(f.read())
    
    for uid, reference_list in ref_data.items():
        all_refs = [uid] + [x.strip() for x in reference_list.split(',')]
        pts_refs = []

        for ref in all_refs:
            if ref.startswith('pts-vp-pli'):
                pts_refs.append(ref)


        for ref in pts_refs:
            pts_to_refs[format_pts(uid, ref)].append({
                'file': path.basename(ref_file).replace('.json', '').replace('_reference', ''),
                'refs': all_refs
            })

# %%
# %%time
language_lookup = {}

for pts_formatted, items in pts_to_refs.items():
    for item in items:
        html_files = glob(path.join(SC_DATA_DIR, 'html_text', 'de', 'pli', '**', item['file'] + '.html'), recursive=True)
        
        for html_file in html_files:
            language = html_file.split('html_text')[1][1:3]
            
            if not language in language_lookup:
                language_lookup[language] = defaultdict(list)

            try:
                with open(html_file) as f:
                    soup = BeautifulSoup(f.read(), 'html.parser')

                article = soup.find('article').attrs
                article_id = article['id']
                assert article_id                

                author = soup.find('meta', { 'name': 'author' })
                author_uid = authors[author['content']]['uid']
                assert author_uid
                
                # find first marker for link
                for ref in item['refs']:
                    marker = soup.find('a', { 'id': ref })

                    if marker:
                        link = 'https://suttacentral.net/%s/%s/%s#%s' % (article_id, language, author_uid, ref)
                        language_lookup[language][pts_formatted].append([article_id, link])
                        break
                print(language_lookup) 
            except Exception as e:
                raise e
                print('error', html_file, e)
# Out:
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']], 'AN i 128': [['an3.28', 'https://suttacentral.net/an3.28/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']], 'AN i 128': [['an3.28', 'https://suttacentral.net/an3.28/de/nyanatiloka#sc1']], 'AN i 129': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc1']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']], 'AN i 128': [['an3.28', 'https://suttacentral.net/an3.28/de/nyanatiloka#sc1']], 'AN i 129': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc1']], 'AN i 130': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc8']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']], 'AN i 128': [['an3.28', 'https://suttacentral.net/an3.28/de/nyanatiloka#sc1']], 'AN i 129': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc1']], 'AN i 130': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc8']], 'AN i 131': [['an3.30', 'https://suttacentral.net/an3.30/de/nyanatiloka#sc2']]})}
# ...
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']], 'AN i 128': [['an3.28', 'https://suttacentral.net/an3.28/de/nyanatiloka#sc1']], 'AN i 129': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc1']], 'AN i 130': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc8']], 'AN i 131': [['an3.30', 'https://suttacentral.net/an3.30/de/nyanatiloka#sc2']], 'AN i 132': [['an3.31', 'https://suttacentral.net/an3.31/de/nyanatiloka#sc1']], 'AN i 133': [['an3.32', 'https://suttacentral.net/an3.32/de/nyanatiloka#sc4']], 'AN i 134': [['an3.33', 'https://suttacentral.net/an3.33/de/nyanatiloka#sc3']], 'AN i 135': [['an3.34', 'https://suttacentral.net/an3.34/de/nyanatiloka#sc4']], 'AN i 136': [['an3.34', 'https://suttacentral.net/an3.34/de/nyanatiloka#sc11']], 'AN i 137': [['an3.35', 'https://suttacentral.net/an3.35/de/nyanatiloka#sc2']], 'AN i 138': [['an3.35', 'https://suttacentral.net/an3.35/de/nyanatiloka#sc7']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']], 'AN i 128': [['an3.28', 'https://suttacentral.net/an3.28/de/nyanatiloka#sc1']], 'AN i 129': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc1']], 'AN i 130': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc8']], 'AN i 131': [['an3.30', 'https://suttacentral.net/an3.30/de/nyanatiloka#sc2']], 'AN i 132': [['an3.31', 'https://suttacentral.net/an3.31/de/nyanatiloka#sc1']], 'AN i 133': [['an3.32', 'https://suttacentral.net/an3.32/de/nyanatiloka#sc4']], 'AN i 134': [['an3.33', 'https://suttacentral.net/an3.33/de/nyanatiloka#sc3']], 'AN i 135': [['an3.34', 'https://suttacentral.net/an3.34/de/nyanatiloka#sc4']], 'AN i 136': [['an3.34', 'https://suttacentral.net/an3.34/de/nyanatiloka#sc11']], 'AN i 137': [['an3.35', 'https://suttacentral.net/an3.35/de/nyanatiloka#sc2']], 'AN i 138': [['an3.35', 'https://suttacentral.net/an3.35/de/nyanatiloka#sc7']], 'AN i 139': [['an3.36', 'https://suttacentral.net/an3.36/de/nyanatiloka#sc4']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']], 'AN i 128': [['an3.28', 'https://suttacentral.net/an3.28/de/nyanatiloka#sc1']], 'AN i 129': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc1']], 'AN i 130': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc8']], 'AN i 131': [['an3.30', 'https://suttacentral.net/an3.30/de/nyanatiloka#sc2']], 'AN i 132': [['an3.31', 'https://suttacentral.net/an3.31/de/nyanatiloka#sc1']], 'AN i 133': [['an3.32', 'https://suttacentral.net/an3.32/de/nyanatiloka#sc4']], 'AN i 134': [['an3.33', 'https://suttacentral.net/an3.33/de/nyanatiloka#sc3']], 'AN i 135': [['an3.34', 'https://suttacentral.net/an3.34/de/nyanatiloka#sc4']], 'AN i 136': [['an3.34', 'https://suttacentral.net/an3.34/de/nyanatiloka#sc11']], 'AN i 137': [['an3.35', 'https://suttacentral.net/an3.35/de/nyanatiloka#sc2']], 'AN i 138': [['an3.35', 'https://suttacentral.net/an3.35/de/nyanatiloka#sc7']], 'AN i 139': [['an3.36', 'https://suttacentral.net/an3.36/de/nyanatiloka#sc4']], 'AN i 140': [['an3.36', 'https://suttacentral.net/an3.36/de/nyanatiloka#sc8']]})}
# {'de': defaultdict(<class 'list'>, {'AN i 98': [['an2.230-279', 'https://suttacentral.net/an2.230-279/de/nyanatiloka#sc1']], 'AN i 101': [['an3.1', 'https://suttacentral.net/an3.1/de/nyanatiloka#sc1']], 'AN i 102': [['an3.2', 'https://suttacentral.net/an3.2/de/nyanatiloka#sc1']], 'AN i 103': [['an3.3', 'https://suttacentral.net/an3.3/de/nyanatiloka#sc2']], 'AN i 104': [['an3.6', 'https://suttacentral.net/an3.6/de/nyanatiloka#sc1']], 'AN i 105': [['an3.9', 'https://suttacentral.net/an3.9/de/nyanatiloka#sc1']], 'AN i 106': [['an3.11', 'https://suttacentral.net/an3.11/de/nyanatiloka#sc1']], 'AN i 108': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc2']], 'AN i 109': [['an3.13', 'https://suttacentral.net/an3.13/de/nyanatiloka#sc5']], 'AN i 110': [['an3.14', 'https://suttacentral.net/an3.14/de/nyanatiloka#sc2']], 'AN i 111': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc1']], 'AN i 112': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc3']], 'AN i 113': [['an3.15', 'https://suttacentral.net/an3.15/de/nyanatiloka#sc6']], 'AN i 114': [['an3.16', 'https://suttacentral.net/an3.16/de/nyanatiloka#sc3']], 'AN i 115': [['an3.18', 'https://suttacentral.net/an3.18/de/nyanatiloka#sc1']], 'AN i 116': [['an3.19', 'https://suttacentral.net/an3.19/de/nyanatiloka#sc3']], 'AN i 117': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc3']], 'AN i 118': [['an3.20', 'https://suttacentral.net/an3.20/de/nyanatiloka#sc6']], 'AN i 119': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc4']], 'AN i 120': [['an3.21', 'https://suttacentral.net/an3.21/de/nyanatiloka#sc8']], 'AN i 121': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc1']], 'AN i 122': [['an3.22', 'https://suttacentral.net/an3.22/de/nyanatiloka#sc8']], 'AN i 123': [['an3.23', 'https://suttacentral.net/an3.23/de/nyanatiloka#sc3']], 'AN i 124': [['an3.25', 'https://suttacentral.net/an3.25/de/nyanatiloka#sc1']], 'AN i 125': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc1']], 'AN i 126': [['an3.26', 'https://suttacentral.net/an3.26/de/nyanatiloka#sc4']], 'AN i 127': [['an3.27', 'https://suttacentral.net/an3.27/de/nyanatiloka#sc2']], 'AN i 128': [['an3.28', 'https://suttacentral.net/an3.28/de/nyanatiloka#sc1']], 'AN i 129': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc1']], 'AN i 130': [['an3.29', 'https://suttacentral.net/an3.29/de/nyanatiloka#sc8']], 'AN i 131': [['an3.30', 'https://suttacentral.net/an3.30/de/nyanatiloka#sc2']], 'AN i 132': [['an3.31', 'https://suttacentral.net/an3.31/de/nyanatiloka#sc1']], 'AN i 133': [['an3.32', 'https://suttacentral.net/an3.32/de/nyanatiloka#sc4']], 'AN i 134': [['an3.33', 'https://suttacentral.net/an3.33/de/nyanatiloka#sc3']], 'AN i 135': [['an3.34', 'https://suttacentral.net/an3.34/de/nyanatiloka#sc4']], 'AN i 136': [['an3.34', 'https://suttacentral.net/an3.34/de/nyanatiloka#sc11']], 'AN i 137': [['an3.35', 'https://suttacentral.net/an3.35/de/nyanatiloka#sc2']], 'AN i 138': [['an3.35', 'https://suttacentral.net/an3.35/de/nyanatiloka#sc7']], 'AN i 139': [['an3.36', 'https://suttacentral.net/an3.36/de/nyanatiloka#sc4']], 'AN i 140': [['an3.36', 'https://suttacentral.net/an3.36/de/nyanatiloka#sc8']], 'AN i 141': [['an3.36', 'https://suttacentral.net/an3.36/de/nyanatiloka#sc13']]})}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/lib64/python3.7/glob.py in glob(pathname, recursive)
#      18     zero or more directories and subdirectories.
#      19     """
# ---> 20     return list(iglob(pathname, recursive=recursive))
#      21
#      22 def iglob(pathname, *, recursive=False):
#
# /usr/lib64/python3.7/glob.py in _iglob(pathname, recursive, dironly)
#      69     else:
#      70         glob_in_dir = _glob0
# ---> 71     for dirname in dirs:
#      72         for name in glob_in_dir(dirname, basename, dironly):
#      73             yield os.path.join(dirname, name)
#
# /usr/lib64/python3.7/glob.py in _iglob(pathname, recursive, dironly)
#      70         glob_in_dir = _glob0
#      71     for dirname in dirs:
# ---> 72         for name in glob_in_dir(dirname, basename, dironly):
#      73             yield os.path.join(dirname, name)
#      74
#
# /usr/lib64/python3.7/glob.py in _glob2(dirname, pattern, dironly)
#     108     assert _isrecursive(pattern)
#     109     yield pattern[:0]
# --> 110     yield from _rlistdir(dirname, dironly)
#     111
#     112 # If dironly is false, yields all file names inside a directory.
#
# /usr/lib64/python3.7/glob.py in _rlistdir(dirname, dironly)
#     136             yield x
#     137             path = os.path.join(dirname, x) if dirname else x
# --> 138             for y in _rlistdir(path, dironly):
#     139                 yield os.path.join(x, y)
#     140
#
# /usr/lib64/python3.7/glob.py in _rlistdir(dirname, dironly)
#     136             yield x
#     137             path = os.path.join(dirname, x) if dirname else x
# --> 138             for y in _rlistdir(path, dironly):
#     139                 yield os.path.join(x, y)
#     140
#
# /usr/lib64/python3.7/glob.py in _rlistdir(dirname, dironly)
#     136             yield x
#     137             path = os.path.join(dirname, x) if dirname else x
# --> 138             for y in _rlistdir(path, dironly):
#     139                 yield os.path.join(x, y)
#     140
#
# /usr/lib64/python3.7/glob.py in _rlistdir(dirname, dironly)
#     131 # Recursively yields relative pathnames inside a literal directory.
#     132 def _rlistdir(dirname, dironly):
# --> 133     names = list(_iterdir(dirname, dironly))
#     134     for x in names:
#     135         if not _ishidden(x):
#
# /usr/lib64/python3.7/glob.py in _iterdir(dirname, dironly)
#     120     try:
#     121         with os.scandir(dirname) as it:
# --> 122             for entry in it:
#     123                 try:
#     124                     if not dironly or entry.is_dir():
#
# KeyboardInterrupt:
